# %%
import pandas as pd
df = pd.read_csv("Accidents.csv")

# %%
population = pd.read_csv('population.csv')

# %%
population
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
population.iloc[:,1]
# Out:
# 5      4779736
# 6       710231
# 7      6392017
# 8      2915918
# 9     37253956
# 10     5029196
# 11     3574097
# 12      897934
# 13      601723
# 14    18801310
# 15     9687653
# 16     1360301
# 17     1567582
# 18    12830632
# 19     6483802
# 20     3046355
# 21     2853118
# 22     4339367
# 23     4533372
# 24     1328361
# 25     5773552
# 26     6547629
# 27     9883640
# 28     5303925
# 29     2967297
# 30     5988927
# 31      989415
# 32     1826341
# 33     2700551
# 34     1316470
# 35     8791894
# 36     2059179
# 37    19378102
# 38     9535483
# 39      672591
# 40    11536504
# 41     3751351
# 42     3831074
# 43    12702379
# 44     1052567
# 45     4625364
# 46      814180
# 47     6346105
# 48    25145561
# 49     2763885
# 50      625741
# 51     8001024
# 52     6724540
# 53     1852994
# 54     5686986
# 55      563626
# 56     3725789
# Name: CENSUS2010POP, dtype: int64

# %%
df.head(10)
# Out:
#      ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0   A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1   A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2   A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3   A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4   A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5   A-6  MapQuest  201.0         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6   A-7  MapQuest  201.0         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7   A-8  MapQuest  201.0         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8   A-9  MapQuest  201.0         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9  A-10  MapQuest  201.0         3  2016-02-08 08:10:04  2016-02-08 08:40:04
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(6,4), dpi= 150)
plt.scatter(df['Start_Lng'],df['Start_Lat'], s=1)

# %%
df.isnull().sum(axis = 0)
# Out:
# ID                             0
# Source                         0
# TMC                       516762
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  1727177
# End_Lng                  1727177
# Distance(mi)                   0
# Description                    1
# Number                   1458402
# Street                         0
# Side                           0
# City                          68
# County                         0
# State                          0
# Zipcode                      646
# Country                        0
# Timezone                    2141
# Airport_Code               23664
# Weather_Timestamp          47170
# Temperature(F)             62265
# Wind_Chill(F)            1852370
# Humidity(%)                64467
# Pressure(in)               57280
# Visibility(mi)             71360
# ...

# %%
sum_all = population['CENSUS2010POP'].sum()
dictionary = {}
for i in range(0, len(population['CENSUS2010POP'])):
    dictionary.update({population['NAME'].iloc[i]:(population['CENSUS2010POP'].iloc[i]/sum_all)})

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))

# %%
for k,v in dictionary.items():
    for i, j in us_state_abbrev.items():
        if (k==i):
            dictionary[j] = dictionary.pop(k)

# %%
dictionary
# Out:
# {'AL': 0.015296558714329651,
#  'AK': 0.0022729477511387788,
#  'AZ': 0.020456331342043426,
#  'AR': 0.009331793825677963,
#  'CA': 0.11922359839435763,
#  'CO': 0.016094903965380478,
#  'CT': 0.011438159892347498,
#  'DE': 0.0028736524679590842,
#  'DC': 0.0019256902890165022,
#  'FL': 0.06016971278775924,
#  'GA': 0.03100333426753105,
#  'HI': 0.0043533626366940225,
#  'ID': 0.005016722702368144,
#  'IL': 0.04106178996705192,
#  'IN': 0.020750070293649694,
#  'IA': 0.009749230526998082,
#  'KS': 0.009130815385182525,
#  'KY': 0.01388724860505361,
#  'LA': 0.014508121572383504,
#  'ME': 0.004251145257881533,
#  'MD': 0.018477061736931786,
#  'MA': 0.020954335435711836,
#  'MI': 0.03163055021685238,
#  'MN': 0.016974117436381612,
#  'MS': 0.009496221712528523,
#  'MO': 0.019166324979315624,
#  'MT': 0.003166418530299262,
#  'NE': 0.005844827483963032,
#  'NV': 0.008642556185643234,
#  'NH': 0.004213090566226577,
#  'NJ': 0.02813664243823562,
#  'NM': 0.006589977454155338,
# ...

# %%
{k: v for k, v in sorted(dictionary.items(), key=lambda item: item[1])}
# Out:
# {'WY': 0.0018037687022720008,
#  'DC': 0.0019256902890165022,
#  'VT': 0.002002554941625092,
#  'ND': 0.0021524886985870547,
#  'AK': 0.0022729477511387788,
#  'SD': 0.0026056150745633055,
#  'DE': 0.0028736524679590842,
#  'MT': 0.003166418530299262,
#  'RI': 0.0033685234741554384,
#  'NH': 0.004213090566226577,
#  'ME': 0.004251145257881533,
#  'HI': 0.0043533626366940225,
#  'ID': 0.005016722702368144,
#  'NE': 0.005844827483963032,
#  'WV': 0.005930124910308971,
#  'NM': 0.006589977454155338,
#  'NV': 0.008642556185643234,
#  'UT': 0.008845243582941613,
#  'KS': 0.009130815385182525,
#  'AR': 0.009331793825677963,
#  'MS': 0.009496221712528523,
#  'IA': 0.009749230526998082,
#  'CT': 0.011438159892347498,
#  'PR': 0.011923618834953135,
#  'OK': 0.01200542474093951,
#  'OR': 0.012260561750678647,
#  'KY': 0.01388724860505361,
#  'LA': 0.014508121572383504,
#  'SC': 0.014802522984772935,
#  'AL': 0.015296558714329651,
#  'CO': 0.016094903965380478,
#  'MN': 0.016974117436381612,
# ...

# %%
accident_norm = df['State'].value_counts(normalize = True).to_dict()

# %%
accident_norm
# Out:
# {'CA': 0.21600676310719677,
#  'TX': 0.10590172014479894,
#  'FL': 0.07909751557417559,
#  'NC': 0.048537861323324744,
#  'NY': 0.047025788134169424,
#  'SC': 0.04451547034032565,
#  'PA': 0.03378612341957602,
#  'MI': 0.03299777756881983,
#  'IL': 0.03195318589319941,
#  'GA': 0.02969644005474302,
#  'VA': 0.02737418441410395,
#  'WA': 0.022496155198514754,
#  'OH': 0.020544230480418587,
#  'AZ': 0.019345891309879636,
#  'OR': 0.018968875713644622,
#  'TN': 0.01892386557745108,
#  'NJ': 0.017979989652125123,
#  'MN': 0.01782579651229378,
#  'LA': 0.016998233909210545,
#  'OK': 0.01612476988010815,
#  'MD': 0.01529230518298403,
#  'CO': 0.011994978473122487,
#  'MA': 0.011629549644620464,
#  'IN': 0.01076767238325106,
#  'UT': 0.010344309716084082,
#  'MO': 0.010018543284821914,
#  'AL': 0.009832263711268444,
#  'NE': 0.008613424874740356,
#  'CT': 0.008337125028799802,
#  'KY': 0.0061343022247930985,
#  'WI': 0.005741689056609827,
#  'IA': 0.0037148959931620246,
# ...

# %%
proportion = {}

# %%
for k,v in dictionary.items():
    for i,j in accident_norm.items():
        if (k==i):
            proportion.update({k:(j,v)})

# %%
proportion = {k: v for k, v in sorted(proportion.items(), key=lambda item: item[1])}

# %%
for k,v in proportion.items():
    proportion.update({k:v*100})

# %%
proportion
# Out:
# {'OH': -1.6375969880877281,
#  'NY': -1.4989828421905813,
#  'WI': -1.2458336061214823,
#  'NJ': -1.0156652786110498,
#  'IN': -0.9982397910398634,
#  'MA': -0.9324785791091371,
#  'MO': -0.914778169449371,
#  'IL': -0.9108604073852506,
#  'AR': -0.8877681659527279,
#  'KY': -0.775294638026051,
#  'MS': -0.7452494142394042,
#  'PA': -0.6865219287462185,
#  'KS': -0.6686007393521434,
#  'IA': -0.6034334533836058,
#  'AL': -0.5464295003061207,
#  'NV': -0.5349685924909765,
#  'WV': -0.5060671685421841,
#  'NM': -0.4856864388247574,
#  'ID': -0.4414210780252614,
#  'CO': -0.40999254922579903,
#  'ME': -0.35470262956459286,
#  'MD': -0.3184756553947756,
#  'CT': -0.3101034863547696,
#  'MT': -0.29730086381408743,
#  'SD': -0.25860066983997826,
#  'ND': -0.2135999836813183,
#  'VT': -0.18162753680716218,
#  'NH': -0.1720598568895099,
#  'WY': -0.1608576230462384,
#  'DE': -0.14814577603489396,
#  'TN': -0.1385533883063259,
#  'GA': -0.13068942127880295,
#  'AZ': -0.11104400321637897,
# ...

# %%
plt.figure(dpi =150)
plt.scatter(accident_norm.keys(), accident_norm.values(), s = 8)
plt.scatter(dictionary.keys(), dictionary.values(), s=8)

# %%
import tabpy_client
conn = tabpy_client.Client("http://localhost:9004/")

# %%
export = pd.DataFrame.from_dict(proportion, orient='index',
                       columns=['Population', 'Accident'])

# %%
export
# Out:
#     Population  Accident
# ND    0.000016  0.002152
# SD    0.000020  0.002606
# VT    0.000186  0.002003
# MT    0.000193  0.003166
# WY    0.000195  0.001804
# AR    0.000454  0.009332
# ID    0.000603  0.005017
# ME    0.000704  0.004251
# WV    0.000869  0.005930
# DC    0.001140  0.001926
# DE    0.001392  0.002874
# NM    0.001733  0.006590
# MS    0.002044  0.009496
# KS    0.002445  0.009131
# NH    0.002492  0.004213
# NV    0.003293  0.008643
# RI    0.003698  0.003369
# IA    0.003715  0.009749
# WI    0.005742  0.018200
# KY    0.006134  0.013887
# CT    0.008337  0.011438
# NE    0.008613  0.005845
# AL    0.009832  0.015297
# MO    0.010019  0.019166
# UT    0.010344  0.008845
# IN    0.010768  0.020750
# MA    0.011630  0.020954
# CO    0.011995  0.016095
# MD    0.015292  0.018477
# OK    0.016125  0.012005
# LA    0.016998  0.014508
# MN    0.017826  0.016974
# NJ    0.017980  0.028137
# TN    0.018924  0.020309
# OR    0.018969  0.012261
# AZ    0.019346  0.020456
# ...

# %%
export.to_csv('export.csv')

# %%
import sys
print(sys.version)
# Out:
# 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
df.select_dtypes('object').apply(pd.Series.nunique, axis=0)
# Out:
# ID                       2243939
# Source                         3
# Start_Time               2086185
# End_Time                 2079472
# Description              1253507
# Street                    136834
# Side                           3
# City                       11077
# County                      1682
# State                         49
# Zipcode                   297430
# Country                        1
# Timezone                       4
# Airport_Code                1895
# Weather_Timestamp         363617
# Wind_Direction                18
# Weather_Condition             61
# Sunrise_Sunset                 2
# Civil_Twilight                 2
# Nautical_Twilight              2
# Astronomical_Twilight          2
# dtype: int64

# %%
Illinois = df.loc[df['State'] == 'IL']

# %%
Illinois
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 167299    A-167300  MapQuest  241.0         2  2016-11-30 14:56:10
# 167300    A-167301  MapQuest  241.0         2  2016-11-30 16:46:21
# 167301    A-167302  MapQuest  201.0         2  2016-11-30 16:47:35
# 167302    A-167303  MapQuest  201.0         2  2016-11-30 17:01:04
# 167303    A-167304  MapQuest  201.0         2  2016-11-30 17:15:22
# ...            ...       ...    ...       ...                  ...
# 2243715  A-2243716      Bing    NaN         3  2017-08-30 17:39:55
# 2243716  A-2243717      Bing    NaN         3  2017-08-30 17:45:10
# 2243717  A-2243718      Bing    NaN         3  2017-08-30 18:10:40
# 2243718  A-2243719      Bing    NaN         3  2017-08-30 18:27:10
# 2243719  A-2243720      Bing    NaN         3  2017-08-30 18:30:55
#
#                     End_Time  Start_Lat  Start_Lng   End_Lat    End_Lng  ...  \
# 167299   2016-11-30 17:10:53  41.816620 -88.168243       NaN        NaN  ...
# ...

# %%
IL = Illinois.drop(['Source','ID','TMC', 'End_Lat', 'End_Lng', 'State', 'Airport_Code', 'Timezone'], axis=1)

# %%
IL.columns
# Out:
# Index(['Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'Distance(mi)', 'Side', 'City', 'County', 'Zipcode', 'Country',
#        'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
Indicators = ['City','Temperature(F)', 'Wind_Speed(mph)', 'Visibility(mi)','Bump', 'Crossing', 'Give_Way','Railway','Weather_Condition','Stop','Severity']

# %%
IL = IL.loc[:, Indicators]

# %%
IL = IL.drop(['Description', 'Number', 'Street'], axis =1)

# %%
IL = IL.drop(['Zipcode', 'Country',
       'Weather_Timestamp','Amenity', 'Bump','End_Time'], axis=1)

# %%
IL = IL.drop(['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
       'Pressure(in)','Wind_Direction', 'Wind_Speed(mph)',
       'Precipitation(in)', 'Weather_Condition'], axis= 1)

# %%
Twilights= ['Severity']

# %%
Twlight = IL.loc[:, Twilights]

# %%
Twlight.columns
# Out:
# Index(['Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight',
#        'Severity'],
#       dtype='object')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Twlight_cat[] = Twlight_cat.apply(le.fit_transform)

# %%
Twlight.iloc[:, 0:3]
# Out:
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 167299             Day               Day                   Day
# 167300             Day               Day                   Day
# 167301             Day               Day                   Day
# 167302           Night               Day                   Day
# 167303           Night               Day                   Day
# ...                ...               ...                   ...
# 2243715            Day               Day                   Day
# 2243716            Day               Day                   Day
# 2243717            Day               Day                   Day
# 2243718            Day               Day                   Day
# 2243719            Day               Day                   Day
#
# [71701 rows x 3 columns]

# %%
Twlight= Twlight.dropna()
Twlight.iloc[:, 0:3] = Twlight.iloc[:,0:3].apply(le.fit_transform)

# %%
Twlight.corr()
# Out:
#                        Civil_Twilight  Nautical_Twilight  \
# Civil_Twilight               1.000000           0.839211
# Nautical_Twilight            0.839211           1.000000
# Astronomical_Twilight        0.708257           0.843956
# Severity                     0.205378           0.211755
#
#                        Astronomical_Twilight  Severity
# Civil_Twilight                      0.708257  0.205378
# Nautical_Twilight                   0.843956  0.211755
# Astronomical_Twilight               1.000000  0.208143
# Severity                            0.208143  1.000000

# %%
# Approximately 20% increase in Severity

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
Twlight_cat = Twlight.select_dtypes(include=[object])
Twlight_cat = Twlight_cat.dropna()
Tw = oe.fit_transform(Twlight_cat)

# %%
Most_severe = Twlight.loc[Twlight['Severity']==4]

# %%
Least_severe = Twlight.loc[Twlight['Severity']==2]

# %%
Least_severe.iloc[:,0].value_counts()
# Out:
# 0    42258
# 1     7553
# Name: Civil_Twilight, dtype: int64

# %%
7553/42258
# Out:
# 0.17873538738227082

# %%
Most_severe.iloc[:, 0].value_counts()
# Out:
# 0    1369
# 1     744
# Name: Civil_Twilight, dtype: int64

# %%
744/1369 #
# Out:
# 0.5434623813002192

# %%
0.5434623813002192-0.17873538738227082
# Out:
# 0.3647269939179484

# %%
#36.5% more likely to be more severe at night

# %%
time = IL['Start_Time']

# %%
Stop = df.loc[df['Stop'] == True]

# %%
NonStop = df.loc[df['Stop']==False]

# %%
NonStop['Severity'].value_counts(normalize = True)
# Out:
# 2    0.646090
# 3    0.321488
# 4    0.032056
# 1    0.000359
# 0    0.000008
# Name: Severity, dtype: float64

# %%
plt.hist(NonStop['Severity'])
# Out:
# (array([1.70000e+01, 0.00000e+00, 7.97000e+02, 0.00000e+00, 0.00000e+00,
#         1.43572e+06, 0.00000e+00, 7.14400e+05, 0.00000e+00, 7.12340e+04]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
Stop['Severity'].value_counts(normalize =True)
# Out:
# 2    0.909650
# 3    0.054292
# 4    0.035276
# 1    0.000781
# Name: Severity, dtype: float64

# %%
plt.hist(Stop['Severity'])
# Out:
# (array([1.7000e+01, 0.0000e+00, 0.0000e+00, 1.9804e+04, 0.0000e+00,
#         0.0000e+00, 1.1820e+03, 0.0000e+00, 0.0000e+00, 7.6800e+02]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
Right = df.loc[df['Side']=="R"]
Left = df.loc[df['Side']=="L"]

# %%
Right['Severity'].value_counts(normalize =True)
# Out:
# 2    0.595225
# 3    0.374699
# 4    0.029796
# 1    0.000273
# 0    0.000008
# Name: Severity, dtype: float64

# %%
Left['Severity'].value_counts(normalize = True)
# Out:
# 2    0.895603
# 3    0.060930
# 4    0.042680
# 1    0.000779
# 0    0.000008
# Name: Severity, dtype: float64

# %%
df['Severity'].value_counts(normalize= True)
# Out:
# 2    0.648647
# 3    0.318895
# 4    0.032087
# 1    0.000363
# 0    0.000008
# Name: Severity, dtype: float64

# %%
Roundabout['Severity'].value_counts(normalize=True) # roundabouts' severity is very low
# Out:
# 2    0.953125
# 4    0.031250
# 3    0.015625
# Name: Severity, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (2,5), dpi=200)
colors = {1:'none', 2:'none', 3:'orange', 4:'red'}
grouped = IL.groupby('Severity')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='Start_Lng', y='Start_Lat', label=key, color=colors[key], s=.2)
#plt.figure(figsize = (2,5), dpi=150)
#plt.show()

# %%
Chicago = df.loc[df['City'] == 'Chicago']

# %%
Chicago
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 167311    A-167312  MapQuest  201.0         2  2016-11-30 17:57:39
# 167322    A-167323  MapQuest  201.0         3  2016-12-01 02:54:26
# 167351    A-167352  MapQuest  241.0         3  2016-12-01 09:45:58
# 167370    A-167371  MapQuest  201.0         2  2016-12-01 16:25:07
# 167376    A-167377  MapQuest  241.0         3  2016-12-01 17:05:16
# ...            ...       ...    ...       ...                  ...
# 2243208  A-2243209      Bing    NaN         2  2017-08-29 14:24:10
# 2243218  A-2243219      Bing    NaN         3  2017-08-29 16:16:40
# 2243224  A-2243225      Bing    NaN         3  2017-08-29 17:08:25
# 2243226  A-2243227      Bing    NaN         3  2017-08-29 17:30:55
# 2243653  A-2243654      Bing    NaN         2  2017-08-30 06:12:10
#
#                     End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  ...  \
# 167311   2016-11-30 18:42:08  41.736378 -87.624580        NaN        NaN  ...
# ...

# %%
fig, ax = plt.subplots(figsize = (2,5), dpi=200)
colors = {1:'green', 2:'blue', 3:'orange', 4:'red'}
grouped = Chicago.groupby('Severity')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='Start_Lng', y='Start_Lat', label=key, color=colors[key], s=.2)

# %%
two[:]=[]
three[:]=[]
four[:]=[]

# %%
two = []
three = []
four = []

# %%
from numpy import nanpercentile 
def get_relativity(column):
    print(column)
    for i in range(0,len(IL[column])):
        if(IL['Severity'].iloc[i]==2):
            two.append(IL[column].iloc[i])
        if(IL['Severity'].iloc[i]==3):
            three.append(IL[column].iloc[i])
        if(IL['Severity'].iloc[i]==4):
            four.append(IL[column].iloc[i])
            
    get_quartiles(two)
    get_quartiles(three)
    get_quartiles(four)
  #  plt.scatter(range(0, len(two)), two, s=.2, color = 'green')
  #   plt.scatter(range(0, len(three)), three, s=.2, color = 'orange')
  #  plt.scatter(range(0, len(four)), four, s=.2, color = 'red')

# %%
import numpy

def get_quartiles(list):
    list = numpy.asarray(list)
    quartile = nanpercentile(list, [25,50,75], axis =0)
    print(numpy.nanstd(list))
    print(quartile)

# %%
columns_compare = ['Side',
       'City', 'County', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
       'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
       'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
       'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Station', 'Stop',
       'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset',
       'Civil_Twilight']

# %%
boolean = IL.select_dtypes(include='bool')

# %%
from sklearn.preprocessing import LabelEncoder 
  
le = LabelEncoder() 

for i in boolean.columns:
    IL[i] = le.fit_transform(IL[i])

# %%
IL['Side'] = le.fit_transform(IL['Side'])

# %%
for i in range(0, len(IL['Civil_Twilight'])):
    if(IL['Civil_Twilight'].iloc[i] == 'Day'):
        IL['Civil_Twilight'].iloc[i] = 0
    else : 
        IL['Civil_Twilight'].iloc[i] =1

# %%
Illinois['Start_Time']
# Out:
# 167299     2016-11-30 14:56:10
# 167300     2016-11-30 16:46:21
# 167301     2016-11-30 16:47:35
# 167302     2016-11-30 17:01:04
# 167303     2016-11-30 17:15:22
#                   ...
# 2243715    2017-08-30 17:39:55
# 2243716    2017-08-30 17:45:10
# 2243717    2017-08-30 18:10:40
# 2243718    2017-08-30 18:27:10
# 2243719    2017-08-30 18:30:55
# Name: Start_Time, Length: 71701, dtype: object

# %%
for i in range(0, len(Illinois['Start_Time'])):
    Illinois['Start_Time'] = pd.to_datetime(Illinois['Start_Time'].iloc[i])
# Out:
# /Users/jaeheukjung/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
type(Illinois['Start_Time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-667fc7673b26> in <module>
# ----> 1 type(Illinois['Start_Time'])
#
# NameError: name 'Illinois' is not defined

# %%
# Out:
# 1
